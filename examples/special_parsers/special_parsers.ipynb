# %% [markdown]
# # Special Parsers
#
# Some of the Tao python commands output special structures in a `;` delimited fashion. Some PyTao methods parse these into more useful structures.

# %%
from pytao import Tao

# %%
tao = Tao("-init $ACC_ROOT_DIR/regression_tests/pipe_test/cesr/tao.init -noplot")

# %% [markdown]
# ## data_d_array

# %%
tao.data_d_array("orbit", "x")[7]
# Out:
# {'ix_d1': 7,
#  'data_type': 'orbit.x',
#  'merit_type': 'target',
#  'ele_ref_name': '',
#  'ele_start_name': '',
#  'ele_name': 'DET_07W',
#  'meas_value': 0.0,
#  'model_value': -0.00909995345025093,
#  'design_value': -0.00909995345025093,
#  'useit_opt': False,
#  'useit_plot': False,
#  'good_user': True,
#  'weight': 1000000.0,
#  'exists': True}

# %% [markdown]
# ## derivative

# %%
tao.cmd("veto var *;veto dat *;")
tao.cmd("use var quad_k1[3:5]")
tao.cmd("set dat orbit.x[1:5]|meas=0")
tao.cmd("use dat orbit.x[1:5]");

# %%
result = tao.derivative()
result
# Out:
# {1: array([[-0.01758468, -0.03303896,  0.00216133],
#         [-0.01711307, -0.03578883,  0.00283783],
#         [ 0.00189157, -0.00956715,  0.002403  ],
#         [-0.00893899,  0.00192382,  0.00267012]])}

# %% [markdown]
# n_datums x n_variables

# %%
result[1].shape
# Out:
# (4, 3)

# %% [markdown]
# ## ele_control_var

# %%
tao.ele_control_var("H01W")
# Out:
# {'HKICK': 0.0}

# %% [markdown]
# ## lat_ele_list

# %%
result = tao.lat_ele_list()

result[0:5]
# Out:
# ['BEGINNING', 'IP_L0', 'CLEO_SOL#3', 'DET_00W', 'CLEO_SOL#4']

# %% [markdown]
# ## matrix

# %%
tao.matrix("beginning", "end")
# Out:
# {'mat6': array([[-9.85453321e-01, -1.78459151e-01, -2.95064264e-02,
#          -3.72328912e-05, -1.28463592e-03,  1.69890832e-03],
#         [ 1.94136498e-01, -9.79571649e-01, -7.19934541e-03,
#           8.91976963e-04, -5.89572298e-03, -3.81443689e-02],
#         [-8.56326169e-04,  6.02559410e-05, -8.76189778e-01,
#          -8.41353610e-03,  1.67854914e-05,  2.64910033e-03],
#         [ 1.16108943e-02,  2.96794811e-02,  2.66272918e+01,
#          -8.85649653e-01,  2.27202188e-05, -4.04349279e-02],
#         [-8.86152164e-02, -6.13453961e-03,  3.48586759e-02,
#          -2.68733720e-03,  9.47817657e-01, -8.79514378e+00],
#         [ 5.30821801e-03, -2.93203403e-04,  1.07833932e-04,
#          -1.59653540e-05,  1.15997844e-02,  9.47355161e-01]]),
#  'vec0': array([ 3.92874185e-04,  4.73093997e-03,  1.86151033e-06, -9.57458176e-05,
#         -7.06702236e-05,  5.03940903e-06])}

# %% [markdown]
# # merit

# %%
tao.merit()
# Out:
# 411.82662194777

# %% [markdown]
# ## plot_list

# %%
result = tao.plot_list("r")

result[0:2]
# Out:
# [{'region': 'top',
#   'ix': 1,
#   'plot_name': '',
#   'visible': False,
#   'x1': 0.0,
#   'x2': 1.0,
#   'y1': 0.48,
#   'y2': 0.95},
#  {'region': 'bottom',
#   'ix': 2,
#   'plot_name': '',
#   'visible': False,
#   'x1': 0.0,
#   'x2': 1.0,
#   'y1': 0.0,
#   'y2': 0.48}]

# %%
# 't' gives a mapping of template plot to index
result = tao.plot_list("t")

result["cbar"]
# Out:
# 5

# %% [markdown]
# ## spin_invariant

# %%
tao.spin_invariant("l0")
# Out:
# array([[ 0.        ,  0.99835693,  0.05730134],
#        [ 0.        ,  0.99835693,  0.05730134],
#        [-0.05286846,  0.99704202,  0.05578657],
#        ...,
#        [-0.24326432,  0.96860132,  0.05132215],
#        [-0.29421324,  0.95443762,  0.04987387],
#        [-0.29421324,  0.95443762,  0.04987387]])

# %% [markdown]
# ## taylor_map

# %%
tt = tao.taylor_map("beginning", "end", order=2)
tt
# Out:
# {1: {(0, 0, 0, 0, 0, 0): -1.66366333206025e-05,
#   (1, 0, 0, 0, 0, 0): -0.985196711977266,
#   (0, 1, 0, 0, 0, 0): -0.179943541572947,
#   (0, 0, 1, 0, 0, 0): -0.0296993930705894,
#   (2, 0, 0, 0, 0, 0): 0.446138630538283,
#   (1, 1, 0, 0, 0, 0): -1.00844385071635,
#   (0, 2, 0, 0, 0, 0): 1.0262270992924,
#   (1, 0, 1, 0, 0, 0): -0.826529708910769,
#   (0, 1, 1, 0, 0, 0): 0.66739198440538,
#   (0, 0, 2, 0, 0, 0): 44.7241377343009,
#   (0, 0, 0, 1, 0, 0): -3.89707865712047e-05,
#   (1, 0, 0, 1, 0, 0): -0.00123736042907706,
#   (0, 1, 0, 1, 0, 0): -0.0371117419952612,
#   (0, 0, 1, 1, 0, 0): -4.03450589575402,
#   (0, 0, 0, 0, 1, 0): -0.00131163342362811,
#   (1, 0, 0, 0, 1, 0): -0.149523686605635,
#   (0, 1, 0, 0, 1, 0): 0.0299336863903886,
#   (0, 0, 1, 0, 1, 0): 0.105807485401765,
#   (0, 0, 0, 0, 0, 1): 0.00175860479787745,
#   (1, 0, 0, 0, 0, 1): 2.90295435624917,
#   (0, 1, 0, 0, 0, 1): 3.49581318940104,
#   (0, 0, 1, 0, 0, 1): 7.97083600944276,
#   (0, 0, 0, 2, 0, 0): -0.0184811091756649,
#   (0, 0, 0, 1, 1, 0): -0.00392766904821308,
#   (0, 0, 0, 0, 2, 0): 0.000742824720599917,
#   (0, 0, 0, 1, 0, 1): 0.0279423368799668,
#   (0, 0, 0, 0, 1, 1): -0.013403239149632,
#   (0, 0, 0, 0, 0, 2): -2.38970874892647},
#  2: {(0, 0, 0, 0, 0, 0): 0.0023904864279507,
#   (1, 0, 0, 0, 0, 0): 0.195138002548964,
#   (0, 1, 0, 0, 0, 0): -0.979350347794501,
#   (0, 0, 1, 0, 0, 0): -0.00732021296373703,
#   (2, 0, 0, 0, 0, 0): 1.32518187370734,
#   (1, 1, 0, 0, 0, 0): -0.169336522543726,
#   (0, 2, 0, 0, 0, 0): 0.295850635050011,
#   (1, 0, 1, 0, 0, 0): -0.962198426835828,
#   (0, 1, 1, 0, 0, 0): 0.697988276117746,
#   (0, 0, 2, 0, 0, 0): 100.484273700823,
#   (0, 0, 0, 1, 0, 0): 0.000900228227275695,
#   (1, 0, 0, 1, 0, 0): 0.0452520346532492,
#   (0, 1, 0, 1, 0, 0): 0.00972374792539452,
#   (0, 0, 1, 1, 0, 0): -2.89154417516533,
#   (0, 0, 0, 0, 1, 0): -0.00589560314413121,
#   (1, 0, 0, 0, 1, 0): -0.060870286487792,
#   (0, 1, 0, 0, 1, 0): 0.131510663032942,
#   (0, 0, 1, 0, 1, 0): 0.0812502967335888,
#   (0, 0, 0, 0, 0, 1): -0.0381872458447488,
#   (1, 0, 0, 0, 0, 1): -9.55225063517756,
#   (0, 1, 0, 0, 0, 1): -5.33575704533732,
#   (0, 0, 1, 0, 0, 1): 4.52924232987249,
#   (0, 0, 0, 2, 0, 0): 0.0629079369965852,
#   (0, 0, 0, 1, 1, 0): -0.0014986359923741,
#   (0, 0, 0, 0, 2, 0): 0.000587990386258827,
#   (0, 0, 0, 1, 0, 1): -0.318535814363309,
#   (0, 0, 0, 0, 1, 1): 0.0412945859165735,
#   (0, 0, 0, 0, 0, 2): 0.766040401214737},
#  3: {(0, 0, 0, 0, 0, 0): 1.05157632154401e-06,
#   (1, 0, 0, 0, 0, 0): -0.000864193360996991,
#   (0, 1, 0, 0, 0, 0): 6.23497462787326e-05,
#   (0, 0, 1, 0, 0, 0): -0.873566454495214,
#   (2, 0, 0, 0, 0, 0): -0.0217554693436211,
#   (1, 1, 0, 0, 0, 0): 0.000631437024484842,
#   (0, 2, 0, 0, 0, 0): -0.0181606451044013,
#   (1, 0, 1, 0, 0, 0): 4.98227519729403,
#   (0, 1, 1, 0, 0, 0): -3.43330388929827,
#   (0, 0, 2, 0, 0, 0): -0.30556110152058,
#   (0, 0, 0, 1, 0, 0): -0.00856834872278798,
#   (1, 0, 0, 1, 0, 0): -0.13265665323952,
#   (0, 1, 0, 1, 0, 0): -0.022053111391554,
#   (0, 0, 1, 1, 0, 0): 0.00641085061278014,
#   (0, 0, 0, 0, 1, 0): 1.68093509107168e-05,
#   (1, 0, 0, 0, 1, 0): 0.00244666075004512,
#   (0, 1, 0, 0, 1, 0): -0.00396412965092215,
#   (0, 0, 1, 0, 1, 0): -0.299055161225772,
#   (0, 0, 0, 0, 0, 1): 0.00264467550374242,
#   (1, 0, 0, 0, 0, 1): 0.319510996431761,
#   (0, 1, 0, 0, 0, 1): 0.014170960769997,
#   (0, 0, 1, 0, 0, 1): -8.2662663644023,
#   (0, 0, 0, 2, 0, 0): -0.00031815504834505,
#   (0, 0, 0, 1, 1, 0): 0.000633772510386498,
#   (0, 0, 0, 0, 2, 0): -2.10025952628046e-05,
#   (0, 0, 0, 1, 0, 1): 0.0846818382436382,
#   (0, 0, 0, 0, 1, 1): -0.00127341296813052,
#   (0, 0, 0, 0, 0, 2): 0.0218741759689182},
#  4: {(0, 0, 0, 0, 0, 0): 1.82087247974924e-06,
#   (1, 0, 0, 0, 0, 0): 0.0117108773238189,
#   (0, 1, 0, 0, 0, 0): 0.0298731605884568,
#   (0, 0, 1, 0, 0, 0): 26.6637945909127,
#   (2, 0, 0, 0, 0, 0): 0.0868126277248976,
#   (1, 1, 0, 0, 0, 0): 0.861048215058761,
#   (0, 2, 0, 0, 0, 0): 0.190819908483242,
#   (1, 0, 1, 0, 0, 0): 92.6293372943798,
#   (0, 1, 1, 0, 0, 0): 46.0396573077618,
#   (0, 0, 2, 0, 0, 0): 0.449570827938597,
#   (0, 0, 0, 1, 0, 0): -0.883232864348147,
#   (1, 0, 0, 1, 0, 0): -0.0824329581313737,
#   (0, 1, 0, 1, 0, 0): 4.59607348850142,
#   (0, 0, 1, 1, 0, 0): 0.608976434965299,
#   (0, 0, 0, 0, 1, 0): 2.46914546543119e-05,
#   (1, 0, 0, 0, 1, 0): 0.0364418547440229,
#   (0, 1, 0, 0, 1, 0): 0.00478839016458798,
#   (0, 0, 1, 0, 1, 0): -0.706485575463062,
#   (0, 0, 0, 0, 0, 1): -0.0404817456314189,
#   (1, 0, 0, 0, 0, 1): -2.75082379222624,
#   (0, 1, 0, 0, 0, 1): -8.49872179381399,
#   (0, 0, 1, 0, 0, 1): -131.350469503354,
#   (0, 0, 0, 2, 0, 0): 0.00467518361912971,
#   (0, 0, 0, 1, 1, 0): 0.276221869131755,
#   (0, 0, 0, 0, 2, 0): -1.88225189288832e-05,
#   (0, 0, 0, 1, 0, 1): 4.50404232618424,
#   (0, 0, 0, 0, 1, 1): 0.0043374316580689,
#   (0, 0, 0, 0, 0, 2): 0.120061711658603},
#  5: {(0, 0, 0, 0, 0, 0): -0.000398882588747221,
#   (1, 0, 0, 0, 0, 0): -0.0886758845710211,
#   (0, 1, 0, 0, 0, 0): -0.00609678196836838,
#   (0, 0, 1, 0, 0, 0): 0.0349098956756242,
#   (2, 0, 0, 0, 0, 0): -4.55774681227228,
#   (1, 1, 0, 0, 0, 0): -3.20536787435449,
#   (0, 2, 0, 0, 0, 0): -2.01689295135513,
#   (1, 0, 1, 0, 0, 0): 6.73098632647396,
#   (0, 1, 1, 0, 0, 0): -7.6713024937591,
#   (0, 0, 2, 0, 0, 0): -193.642692180716,
#   (0, 0, 0, 1, 0, 0): -0.0026838991204717,
#   (1, 0, 0, 1, 0, 0): -0.31118102260141,
#   (0, 1, 0, 1, 0, 0): -0.0386794220756567,
#   (0, 0, 1, 1, 0, 0): 7.80657927343161,
#   (0, 0, 0, 0, 1, 0): 0.947807431278623,
#   (1, 0, 0, 0, 1, 0): 0.0365678219437706,
#   (0, 1, 0, 0, 1, 0): 0.00969286376291696,
#   (0, 0, 1, 0, 1, 0): -0.0420696936049426,
#   (0, 0, 0, 0, 0, 1): -8.7950464022494,
#   (1, 0, 0, 0, 0, 1): 1.24481687862007,
#   (0, 1, 0, 0, 0, 1): 5.21712425253881,
#   (0, 0, 1, 0, 0, 1): 1.11928480447668,
#   (0, 0, 0, 2, 0, 0): -0.0114705893951145,
#   (0, 0, 0, 1, 1, 0): 0.00185585821442935,
#   (0, 0, 0, 0, 2, 0): -0.000315809123743831,
#   (0, 0, 0, 1, 0, 1): -0.0077199161222233,
#   (0, 0, 0, 0, 1, 1): 0.0125208058903836,
#   (0, 0, 0, 0, 0, 2): 0.356233037976673},
#  6: {(0, 0, 0, 0, 0, 0): -7.15739820376974e-06,
#   (1, 0, 0, 0, 0, 0): 0.00531272324489455,
#   (0, 1, 0, 0, 0, 0): -0.000311133778861207,
#   (0, 0, 1, 0, 0, 0): 0.000106214740364635,
#   (2, 0, 0, 0, 0, 0): -0.00980559782184324,
#   (1, 1, 0, 0, 0, 0): -0.176228169290618,
#   (0, 2, 0, 0, 0, 0): -0.0276151784337879,
#   (1, 0, 1, 0, 0, 0): -0.0170044377905568,
#   (0, 1, 1, 0, 0, 0): 0.00529167735928539,
#   (0, 0, 2, 0, 0, 0): 2.02217491410271,
#   (0, 0, 0, 1, 0, 0): -1.59179293431318e-05,
#   (1, 0, 0, 1, 0, 0): -0.00164375561730268,
#   (0, 1, 0, 1, 0, 0): -0.00408622392217045,
#   (0, 0, 1, 1, 0, 0): -0.155773825194423,
#   (0, 0, 0, 0, 1, 0): 0.0115997890387502,
#   (1, 0, 0, 0, 1, 0): -0.000232280149869492,
#   (0, 1, 0, 0, 1, 0): 0.00142719873759487,
#   (0, 0, 1, 0, 1, 0): 0.000135567383097398,
#   (0, 0, 0, 0, 0, 1): 0.947365021172658,
#   (1, 0, 0, 0, 0, 1): -0.0563005140544777,
#   (0, 1, 0, 0, 0, 1): 0.0132278366367463,
#   (0, 0, 1, 0, 0, 1): 0.00296081630017153,
#   (0, 0, 0, 2, 0, 0): -0.000889800681387032,
#   (0, 0, 0, 1, 1, 0): -1.09693033156737e-07,
#   (0, 0, 0, 0, 2, 0): 4.33263383227185e-06,
#   (0, 0, 0, 1, 0, 1): -0.00200395730557734,
#   (0, 0, 0, 0, 1, 1): 0.000904654952386955,
#   (0, 0, 0, 0, 0, 2): 0.00957353207511102}}

# %%
# Compare some terms with the matrix calc:
tao.matrix("beginning", "end")["mat6"][0, 0], tt[1][(1, 0, 0, 0, 0, 0)]
# Out:
# (np.float64(-0.985453321293509), -0.985196711977266)

# %%
tao.matrix("beginning", "end")["mat6"][1, 0], tt[2][(1, 0, 0, 0, 0, 0)]
# Out:
# (np.float64(0.194136497704459), 0.195138002548964)

# %% [markdown]
# ## var_v_array

# %%
result = tao.var_v_array("quad_k1")
result[0:2]
# Out:
# [{'ix_v1': 0,
#   'var_attrib_name': 'Q00W[K1]',
#   'meas_value': 0.0,
#   'model_value': -0.841784836453016,
#   'design_value': -0.841784836453016,
#   'useit_opt': False,
#   'good_user': False,
#   'weight': 100000.0},
#  {'ix_v1': 3,
#   'var_attrib_name': 'Q03W[K1]',
#   'meas_value': 0.0,
#   'model_value': -0.128947,
#   'design_value': -0.128947,
#   'useit_opt': True,
#   'good_user': True,
#   'weight': 100000.0}]
