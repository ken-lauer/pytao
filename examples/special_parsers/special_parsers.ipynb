# %% [markdown]
# # Special Parsers
#
# Some of the Tao python commands output special structures in a `;` delimited fashion. Some PyTao methods parse these into more useful structures.

# %%
from pytao import Tao

# %%
tao = Tao("-init $ACC_ROOT_DIR/regression_tests/pipe_test/cesr/tao.init -noplot")

# %% [markdown]
# ## data_d_array

# %%
tao.data_d_array("orbit", "x")[7]
# Out:
# {'ix_d1': 7,
#  'data_type': 'orbit.x',
#  'merit_type': 'target',
#  'ele_ref_name': '',
#  'ele_start_name': '',
#  'ele_name': 'DET_07W',
#  'meas_value': 0.0,
#  'model_value': -0.00909995345022744,
#  'design_value': -0.00909995345022744,
#  'useit_opt': False,
#  'useit_plot': False,
#  'good_user': True,
#  'weight': 1000000.0,
#  'exists': True}

# %% [markdown]
# ## derivative

# %%
tao.cmd("veto var *;veto dat *;")
tao.cmd("use var quad_k1[3:5]")
tao.cmd("set dat orbit.x[1:5]|meas=0")
tao.cmd("use dat orbit.x[1:5]");

# %%
result = tao.derivative()
result
# Out:
# {1: array([[-0.01758468, -0.03303896,  0.00216133],
#         [-0.01711307, -0.03578883,  0.00283783],
#         [ 0.00189157, -0.00956715,  0.002403  ],
#         [-0.00893899,  0.00192381,  0.00267012]])}

# %% [markdown]
# n_datums x n_variables

# %%
result[1].shape
# Out:
# (4, 3)

# %% [markdown]
# ## ele_control_var

# %%
tao.ele_control_var("H01W")
# Out:
# {'HKICK': 0.0}

# %% [markdown]
# ## lat_ele_list

# %%
result = tao.lat_ele_list()

result[0:5]
# Out:
# ['BEGINNING', 'IP_L0', 'CLEO_SOL#3', 'DET_00W', 'CLEO_SOL#4']

# %% [markdown]
# ## matrix

# %%
tao.matrix("beginning", "end")
# Out:
# {'mat6': array([[-9.85453321e-01, -1.78459151e-01, -2.95064264e-02,
#          -3.72328912e-05, -1.28463592e-03,  1.69890832e-03],
#         [ 1.94136498e-01, -9.79571649e-01, -7.19934541e-03,
#           8.91976963e-04, -5.89572298e-03, -3.81443689e-02],
#         [-8.56326169e-04,  6.02559410e-05, -8.76189778e-01,
#          -8.41353610e-03,  1.67854914e-05,  2.64910033e-03],
#         [ 1.16108943e-02,  2.96794811e-02,  2.66272918e+01,
#          -8.85649653e-01,  2.27202188e-05, -4.04349279e-02],
#         [-8.86152164e-02, -6.13453961e-03,  3.48586759e-02,
#          -2.68733720e-03,  9.47817657e-01, -8.79514378e+00],
#         [ 5.30821801e-03, -2.93203403e-04,  1.07833932e-04,
#          -1.59653540e-05,  1.15997844e-02,  9.47355161e-01]]),
#  'vec0': array([ 3.92874185e-04,  4.73093997e-03,  1.86151033e-06, -9.57458176e-05,
#         -7.06702236e-05,  5.03940903e-06])}

# %% [markdown]
# # merit

# %%
tao.merit()
# Out:
# 411.826621947753

# %% [markdown]
# ## plot_list

# %%
result = tao.plot_list("r")

result[0:2]
# Out:
# [{'region': 'top',
#   'ix': 1,
#   'plot_name': '',
#   'visible': False,
#   'x1': 0.0,
#   'x2': 1.0,
#   'y1': 0.48,
#   'y2': 0.95},
#  {'region': 'bottom',
#   'ix': 2,
#   'plot_name': '',
#   'visible': False,
#   'x1': 0.0,
#   'x2': 1.0,
#   'y1': 0.0,
#   'y2': 0.48}]

# %%
# 't' gives a mapping of template plot to index
result = tao.plot_list("t")

result["cbar"]
# Out:
# 5

# %% [markdown]
# ## spin_invariant

# %%
tao.spin_invariant("l0")
# Out:
# array([[ 0.        ,  0.99835693,  0.05730134],
#        [ 0.        ,  0.99835693,  0.05730134],
#        [-0.05286846,  0.99704202,  0.05578657],
#        ...,
#        [-0.24326432,  0.96860132,  0.05132215],
#        [-0.29421324,  0.95443762,  0.04987387],
#        [-0.29421324,  0.95443762,  0.04987387]])

# %% [markdown]
# ## taylor_map

# %%
tt = tao.taylor_map("beginning", "end", order=2)
tt
# Out:
# {1: {(0, 0, 0, 0, 0, 0): -1.66366332734187e-05,
#   (1, 0, 0, 0, 0, 0): -0.985196712193085,
#   (0, 1, 0, 0, 0, 0): -0.179943541430375,
#   (0, 0, 1, 0, 0, 0): -0.0296993930581312,
#   (2, 0, 0, 0, 0, 0): 0.44599023014603,
#   (1, 1, 0, 0, 0, 0): -1.00824920631382,
#   (0, 2, 0, 0, 0, 0): 1.02616331863598,
#   (1, 0, 1, 0, 0, 0): -0.826513025694012,
#   (0, 1, 1, 0, 0, 0): 0.667381046226588,
#   (0, 0, 2, 0, 0, 0): 44.7241373503535,
#   (0, 0, 0, 1, 0, 0): -3.89707866114858e-05,
#   (1, 0, 0, 1, 0, 0): -0.00123740200263406,
#   (0, 1, 0, 1, 0, 0): -0.0371117147505347,
#   (0, 0, 1, 1, 0, 0): -4.03450589562478,
#   (0, 0, 0, 0, 1, 0): -0.00131163342264003,
#   (1, 0, 0, 0, 1, 0): -0.149522460201519,
#   (0, 1, 0, 0, 1, 0): 0.0299328821439314,
#   (0, 0, 1, 0, 1, 0): 0.10580741646538,
#   (0, 0, 0, 0, 0, 1): 0.00175860486370104,
#   (1, 0, 0, 0, 0, 1): 2.90304519667983,
#   (0, 1, 0, 0, 0, 1): 3.4957536543052,
#   (0, 0, 1, 0, 0, 1): 7.97083090345852,
#   (0, 0, 0, 2, 0, 0): -0.0184811091716708,
#   (0, 0, 0, 1, 1, 0): -0.00392766887643744,
#   (0, 0, 0, 0, 2, 0): 0.000742822186168254,
#   (0, 0, 0, 1, 0, 1): 0.027942349699787,
#   (0, 0, 0, 0, 1, 1): -0.0134036145215192,
#   (0, 0, 0, 0, 0, 2): -2.38972265610164},
#  2: {(0, 0, 0, 0, 0, 0): 0.0023904864274779,
#   (1, 0, 0, 0, 0, 0): 0.195138002091039,
#   (0, 1, 0, 0, 0, 0): -0.979350347497057,
#   (0, 0, 1, 0, 0, 0): -0.00732021293814876,
#   (2, 0, 0, 0, 0, 0): 1.32487072553184,
#   (1, 1, 0, 0, 0, 0): -0.168928442627978,
#   (0, 2, 0, 0, 0, 0): 0.295716925234395,
#   (1, 0, 1, 0, 0, 0): -0.962163461377072,
#   (0, 0, 0, 1, 1, 0): 0.00185573787320566,
#   (0, 0, 0, 0, 2, 0): -0.000314020730525314,
#   (0, 0, 0, 1, 0, 1): -0.00772890065262779,
#   (0, 0, 0, 0, 1, 1): 0.0127857100390145,
#   (0, 0, 0, 0, 0, 2): 0.366048525138544},
#  6: {(0, 0, 0, 0, 0, 0): -7.15739820305047e-06,
#   (1, 0, 0, 0, 0, 0): 0.00531272416231445,
#   (0, 1, 0, 0, 0, 0): -0.000311134380036052,
#   (0, 0, 1, 0, 0, 0): 0.000106214688850704,
#   (2, 0, 0, 0, 0, 0): -0.00918158475799455,
#   (1, 1, 0, 0, 0, 0): -0.177046573442671,
#   (0, 2, 0, 0, 0, 0): -0.0273470258752819,
#   (1, 0, 1, 0, 0, 0): -0.017074549199079,
#   (0, 1, 1, 0, 0, 0): 0.00533764149667744,
#   (0, 0, 2, 0, 0, 0): 2.02217650989811,
#   (0, 0, 0, 1, 0, 0): -1.59179292155699e-05,
#   (1, 0, 0, 1, 0, 0): -0.00164358206520181,
#   (0, 1, 0, 1, 0, 0): -0.00408633763628882,
#   (0, 0, 1, 1, 0, 0): -0.155773826441374,
#   (0, 0, 0, 0, 1, 0): 0.0115997890349742,
#   (1, 0, 0, 0, 1, 0): -0.000237436469529805,
#   (0, 1, 0, 0, 1, 0): 0.00143057987749665,
#   (0, 0, 1, 0, 1, 0): 0.000135857053201451,
#   (0, 0, 0, 0, 0, 1): 0.947365020894141,
#   (1, 0, 0, 0, 0, 1): -0.0566824855902065,
#   (0, 1, 0, 0, 0, 1): 0.0134781546971454,
#   (0, 0, 1, 0, 0, 1): 0.00298227406434306,
#   (0, 0, 0, 2, 0, 0): -0.000889800653948003,
#   (0, 0, 0, 1, 1, 0): -1.10409975044243e-07,
#   (0, 0, 0, 0, 2, 0): 4.34328835487212e-06,
#   (0, 0, 0, 1, 0, 1): -0.00200401083148869,
#   (0, 0, 0, 0, 1, 1): 0.00090623314599244,
#   (0, 0, 0, 0, 0, 2): 0.00963200872266312}}

# %%
# Compare some terms with the matrix calc:
tao.matrix("beginning", "end")["mat6"][0, 0], tt[1][(1, 0, 0, 0, 0, 0)]
# Out:
# (np.float64(-0.985453321293528), -0.985196712193085)

# %%
tao.matrix("beginning", "end")["mat6"][1, 0], tt[2][(1, 0, 0, 0, 0, 0)]
# Out:
# (np.float64(0.194136497704456), 0.195138002091039)

# %% [markdown]
# ## var_v_array

# %%
result = tao.var_v_array("quad_k1")
result[0:2]
# Out:
# [{'ix_v1': 0,
#   'var_attrib_name': 'Q00W[K1]',
#   'meas_value': 0.0,
#   'model_value': -0.841784836453016,
#   'design_value': -0.841784836453016,
#   'useit_opt': False,
#   'good_user': False,
#   'weight': 100000.0},
#  {'ix_v1': 3,
#   'var_attrib_name': 'Q03W[K1]',
#   'meas_value': 0.0,
#   'model_value': -0.128947,
#   'design_value': -0.128947,
#   'useit_opt': True,
#   'good_user': True,
#   'weight': 100000.0}]
